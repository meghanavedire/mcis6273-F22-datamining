# %% [markdown]
# \*\* Assignment 0 \*\*
#
# -   Zotero Username : meghanavedire
#
# -   Zotero Mail : MVedire2642@muleriders.saumag.edu
#
# # 1)List 3 things that you learned from this podcast?
#
# The Talk Python podcast was quite educational all around. Here is a list
# of the things I discovered from the podcast:
#
# -   Adam described the advantages that Jupyter notebook and Github have
#     brought to the data industry. Knowing this turned out to be quite
#     advantageous. especially because Github has uses outside of academia
#
# -   The computational notebooks accurately provide the computational
#     story using a cell-by-cell specification in the notebook.
#
# -   Using notebooks has expanded data science’s utility for students,
#     which is amazing given how it can be used to so many various
#     businesses.
#
# # 2) What is your reaction to the podcast? Pick at least one point Adam brought up in the interview that you agree with and list your reason why
#
# It’s true that the line in the audio that reads, “It is exciting that,
# You get to build things that is conceptual but it runs.” In spite of the
# fact that this space is entirely virtual, you still get to build things.
# But doing so would considerably elevate the stakes. If you comprehend
# things more deeply, you will see they are indeed true. I have no doubt
# that people are able to create significant, if virtual, objects. After
# listening to the podcast, I’m eager to learn more about it.
#
# # 3) After listening to the podcast, do you think you are more interested or less interested in learning from Jupyter notebooks on Github?
#
# In my viewpoint, the best place for a beginner to begin on this awesome
# experience is with a Jupyter notebook. I enjoy working on Github and
# notebooks. After listening to the episode, I believe that I have a
# greater interest in learning from Jupyter notebooks on GitHub.
